# %%
#1 ans
Name="Sindhu"
print(Name)
# Out:
# Sindhu

# %%
#2 ans
Age=20
print(Age)
# Out:
# 20

# %%
#3 ans
list=[5,5]
print(sum(list))
# Out:
# 10

# %%
#4 ans
a=10
b=9
difference_num=a-b
print(difference_num,"difference between a & b")
# Out:
# 1 difference between a & b

# %%
#5 ans
a=5
b=4
product=a*b
print(product)
# Out:
# 20

# %%
#6 ans
a=12
b=5
div=a/b
print(div)
# Out:
# 2.4

# %%
#7 ans
length=float(input("enter the length:"))
breadth=float(input("enter the breadth:"))
area=length*breadth
print("Area of rectangle is: ",area)
# Out:
# enter the length:8
# enter the breadth:9
# Area of rectangle is:  72.0

# %%
#8 ans
length=float(input("enter the length:"))
breadth=float(input("enter the breadth:"))
area=length*breadth
print("Area of rectangle is:",area)
perimeter=2*(length+breadth)
print("perimeter of rectangle is:",perimeter)
# Out:
# enter the length:9
# enter the breadth:7
# Area of rectangle is: 63.0
# perimeter of rectangle is: 32.0

# %%
#9 ans
radius=float(input("enter the radius value:"))
area=3.14*radius**2
print("Area of circle is:",area)
# Out:
# enter the radius value:14
# Area of circle is: 615.44

# %%
#10 ans
cel=float(input("enter the celsius value:"))
farh=((cel+32)*9)/5
print("Farhrenhit temperature is:",farh)
# Out:
# enter the celsius value:79
# Farhrenhit temperature is: 199.8

# %%
#11 ans
t=89
e=90
m=95
s=92
ss=87
total=500
obtain=t+e+m+s+ss
print("Obtain marks is ",obtain,"out of 500")
# Out:
# Obtain marks is  453 out of 500

# %%
#12 ans
a=5
b=7
c=9
avg=(a+b+c)/3
print(avg)
# Out:
# 7.0

# %%
#13 ans
meter=float(input("enter the meter value:"))
cm=meter*100
print("cm is",cm)
# Out:
# enter the meter value:78.8
# cm is 7880.0

# %%
#14 ans
klm=float(input("enter the kilometer value:"))
meter=klm*1000
print("Meter value is",meter)
# Out:
# enter the kilometer value:50.88
# Meter value is 50880.0

# %%
#15 ans

# %%
#16 ans
x="car"
y="bike"
z=0
z=x
x=y
y=z
print("x is",x)
print("y is",y)
# Out:
# x is bike
# y is car

# %%
#17 ans
name=input("enter your name:")
print("Hello,",name)
# Out:
# enter your name:sindhu
# Hello, sindhu

# %%
#18 ans
num_1=int(input("enter the number 1:"))
num_2=int(input("enter the number 2:"))
add=num_1 + num_2
print("Total value is",add)
# Out:
# enter the number 1:19
# enter the number 2:11
# Total value is 30

# %%
#19 ans
age=int(input("enter your age:"))
after=age+5
print("After 5 years age is",after)
# Out:
# enter your age:20
# After 5 years age is 25

# %%
#20 ans
length=float(input("enter the length value:"))
breadth=float(input("enter the breadth value:"))
area=length*breadth
print("area of rectangle:",area)
# Out:
# enter the length value:5.5
# enter the breadth value:7
# area of rectangle: 38.5

# %%
#21 ans
a=23
b="star"
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#22 ans
a=55
print(float(a))
print(type(a))
# Out:
# 55.0
# <class 'int'>

# %%
#23 ans
x=56.8
print(int(x))
print(type(x))
# Out:
# 56
# <class 'float'>

# %%
#24 ans
z="123"
print(int(z))
print(type(z))
# Out:
# 123
# <class 'str'>

# %%
#25 ans
a=789
b=str(a)
print(b)
print(type(b))
# Out:
# 789
# <class 'str'>

# %%
#26 ans
a=23
b=4.6
c="car"
d=True
print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))
# Out:
# 23 <class 'int'>
# 4.6 <class 'float'>
# car <class 'str'>
# True <class 'bool'>

# %%
#27 ans
x=float(input("enter the value:"))
square=x**2
print("square value is",square)
# Out:
# enter the value:8
# square value is 64.0

# %%
#28 ans
x=float(input("enter the value:"))
cube=x**3
print("cube value is",cube)
# Out:
# enter the value:3
# cube value is 27.0

# %%
#29 ans
product_1=250
product_2=500
product_3=200
total_price=product_1+product_2+product_3
print(product_1,"1st product price",total_price)
print(product_2,"2nd product price",total_price)
print(product_3,"3rd product price",total_price)
# Out:
# 250 1st product price 950
# 500 2nd product price 950
# 200 3rd product price 950

# %%
#30 ans
name=input("enter your name:")
sub_1=int(input("enter the mark:"))
sub_2=int(input("enter the mark"))
sub_3=int(input("enter the mark"))
total=sub_1+sub_2+sub_3
avg=total/3
print("Name:",name)
print("Total marks:",total)
print("Average marks:",avg)
# Out:
# enter your name:sindhu
# enter the mark:98
# enter the mark89
# enter the mark95
# Name: sindhu
# Total marks: 282
# Average marks: 94.0
